# %% [markdown]
# <a href="https://colab.research.google.com/github/denis-couras/ABGaugeViewKit/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/train_labels.csv')

# %%
df.head()
# Out:
#    Volcano?  Type  Radius  Number Volcanoes
# 0         1   3.0   17.46               1.0
# 1         0   NaN     NaN               NaN
# 2         0   NaN     NaN               NaN
# 3         0   NaN     NaN               NaN
# 4         0   NaN     NaN               NaN

# %%
df.shape
# Out:
# (7000, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7000 entries, 0 to 6999
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Volcano?          7000 non-null   int64
#  1   Type              1000 non-null   float64
#  2   Radius            1000 non-null   float64
#  3   Number Volcanoes  1000 non-null   float64
# dtypes: float64(3), int64(1)
# memory usage: 218.9 KB

# %%
df['Radius'].value_counts()
# Out:
# Radius
# 5.000000     35
# 2.830000     30
# 4.240000     30
# 5.390000     27
# 3.610000     25
#              ..
# 49.770000     1
# 32.650002     1
# 16.969999     1
# 31.139999     1
# 27.020000     1
# Name: count, Length: 333, dtype: int64

# %%
df.describe()
# Out:
#           Volcano?         Type       Radius  Number Volcanoes
# count  7000.000000  1000.000000  1000.000000       1000.000000
# mean      0.142857     2.965000    16.257650          1.236000
# std       0.349952     0.984248    11.632887          0.553724
# min       0.000000     1.000000     1.000000          1.000000
# 25%       0.000000     2.000000     5.830000          1.000000
# 50%       0.000000     3.000000    14.870000          1.000000
# 75%       0.000000     4.000000    23.555001          1.000000
# max       1.000000     4.000000    87.660000          5.000000

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
df.hist(bins=50, figsize=(20,15))
plt.show()

# %%
from sklearn.model_selection import train_test_split
df_train, df_test = train_test_split(df, test_size=0.2, random_state=7)

# %%
print(len(df_train), "train +", len(df_test), "test")
# Out:
# 5600 train + 1400 test

# %%
# Escrever um DataFrame no arquivo .h5
df = pd.DataFrame({'coluna1': [1, 2, 3], 'coluna2': [3, 8, 25], 'column3': [10, 15, 1500]})
df.to_hdf('arquivo.h5', key='meus_dados', mode='w')

# %%
# Ler o DataFrame do arquivo .h5
df_lido = pd.read_hdf('arquivo.h5')
print(df_lido)
# Out:
#    coluna1  coluna2  column3
# 0        1        3       10
# 1        2        8       15
# 2        3       25     1500

# %%
df_lido.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   coluna1  3 non-null      int64
#  1   coluna2  3 non-null      int64
#  2   column3  3 non-null      int64
# dtypes: int64(3)
# memory usage: 96.0 bytes

# %%
df_lido.describe()
# Out:
#        coluna1    coluna2      column3
# count      3.0   3.000000     3.000000
# mean       2.0  12.000000   508.333333
# std        1.0  11.532563   858.812164
# min        1.0   3.000000    10.000000
# 25%        1.5   5.500000    12.500000
# 50%        2.0   8.000000    15.000000
# 75%        2.5  16.500000   757.500000
# max        3.0  25.000000  1500.000000

# %%
df_lido.shape
# Out:
# (3, 3)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
df_lido.hist(bins=50, figsize=(20,15))
plt.show()
